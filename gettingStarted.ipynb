# %% [markdown]
# <a href="https://colab.research.google.com/github/MatthewCNorton/SnOasis/blob/main/gettingStarted.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
s = 0

for i in range(10):
  s += i

print(s)
# Out:
# 45

# %%
import pandas as pd

# %%
snoasisData = pd.read_csv("https://raw.githubusercontent.com/nurfnick/SnOasis/main/snoasisData.csv")

# %%
snoasisData.head()
# Out:
#         Date        Time          Staff  Receipt number       Name  Variant  \
# 0  2/28/2023  7:50:56?PM   SnOasis Main               1  Gift card      NaN
# 1  2/28/2023  7:52:12?PM   SnOasis Main               2  Gift card      NaN
# 2  2/28/2023  7:58:14?PM   SnOasis Main               3  Gift card      NaN
# 3  2/28/2023  8:21:15?PM   SnOasis Main               4  Candy Bar      NaN
# 4  2/28/2023  9:29:15?PM  SnOasis  East               5  Gift card      NaN
#
#    Unit  Quantity  Price (USD)  Discount (USD)  Subtotal (USD)  \
# 0   NaN         1          1.0             0.0             1.0
# 1   NaN         1          1.0             0.0             1.0
# 2   NaN         1          1.0             0.0             1.0
# 3   NaN         1          1.5             0.0             1.5
# 4   NaN         1          1.0             0.0             1.0
#
#   Tax Info Available Is Tax Exempt  Total tax collected (USD)  \
# 0                 No            No                       0.00
# ...

# %%
snoasisData.Quantity.sum()
# Out:
# 111564

# %%
snoasisData.describe()
# Out:
#        Receipt number  Variant  Unit      Quantity   Price (USD)  \
# count    76219.000000      0.0   0.0  76219.000000  76219.000000
# mean     18402.852281      NaN   NaN      1.463730      2.628208
# std      10704.917961      NaN   NaN      0.866411      2.384576
# min          1.000000      NaN   NaN     -6.000000    -12.000000
# 25%       9205.500000      NaN   NaN      1.000000      1.000000
# 50%      18360.000000      NaN   NaN      1.000000      2.000000
# 75%      27631.500000      NaN   NaN      2.000000      3.500000
# max      37196.000000      NaN   NaN     40.000000    104.500000
#
#        Discount (USD)  Subtotal (USD)  Total tax collected (USD)  \
# count    76219.000000    76219.000000               76219.000000
# mean        -0.000861        6.508251                   0.245802
# std          0.057335        9.356876                   0.219810
# min         -8.150000      -12.500000                  -1.130000
# ...
